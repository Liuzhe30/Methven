# %%
import pandas as pd
import numpy as np
import seaborn as sns
from prettytable import PrettyTable
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
balanced_path = '../datasets/labeled/'

fig = plt.figure(figsize=(14,3))
data = pd.DataFrame()

for i in range(22):
    chr = 'chr' + str(i+1)
    table1 = pd.read_pickle(balanced_path + chr + '_small.dataset')
    table2 = pd.read_pickle(balanced_path + chr + '_large.dataset')

    num1 = table1.shape[0]
    num2 = table2.shape[0]

    data = data._append({'chr':chr, 'group':'1-10kbp','value count':num1},ignore_index=True)
    data = data._append({'chr':chr, 'group':'10k-100kbp','value count':num2},ignore_index=True)

#print(data.head())
color=['#9DD0C7','#9180AC','#D6AFB9']
sns.barplot(x='chr', y='value count', hue='group', data=data, palette=sns.set_palette(color)) 
plt.title('Distribution of samples (origin)', fontsize=15)
plt.savefig('images/sample-count1.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
balanced_path = '../datasets/sampled/'

fig = plt.figure(figsize=(14,3))
data = pd.DataFrame()

for i in range(22):
    chr = 'chr' + str(i+1)
    table1 = pd.read_pickle(balanced_path + chr + '_small.dataset')
    table2 = pd.read_pickle(balanced_path + chr + '_large.dataset')

    num1 = table1.shape[0]
    num2 = table2.shape[0]

    data = data._append({'chr':chr, 'group':'1-10kbp','value count':num1},ignore_index=True)
    data = data._append({'chr':chr, 'group':'10k-100kbp','value count':num2},ignore_index=True)

#print(data.head())
color=['#9DD0C7','#9180AC','#D6AFB9']
sns.barplot(x='chr', y='value count', hue='group', data=data, palette=sns.set_palette(color)) 
plt.title('Distribution of samples (balanced sampling)', fontsize=15)
plt.savefig('images/sample-count2.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
balanced_path = '../data/chr_final_count/'

fig = plt.figure(figsize=(14,3))
data = pd.DataFrame()

for i in range(22):
    chr = 'chr' + str(i+1)
    table1 = pd.read_pickle(balanced_path + chr + '_small.dataset')
    table2 = pd.read_pickle(balanced_path + chr + '_large.dataset')

    num1 = table1.shape[0]
    num2 = table2.shape[0]

    data = data._append({'chr':chr, 'group':'1-10kbp','value count':num1},ignore_index=True)
    data = data._append({'chr':chr, 'group':'10k-100kbp','value count':num2},ignore_index=True)

#print(data.head())
color=['#9DD0C7','#9180AC','#D6AFB9']
sns.barplot(x='chr', y='value count', hue='group', data=data, palette=sns.set_palette(color)) 
plt.title('Distribution of samples (down-sampling)', fontsize=15)
plt.savefig('images/sample-count3.png',dpi=300, bbox_inches = 'tight')
plt.show()
