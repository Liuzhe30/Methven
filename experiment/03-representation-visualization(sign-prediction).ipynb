# %% [markdown]
# #### representation visualization of EMO model

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import datasets
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

def plot_embedding(data, label, title):
    x_min, x_max = np.min(data, 0), np.max(data, 0)
    data = (data - x_min) / (x_max - x_min)

    fig = plt.figure()
    ax = plt.subplot(111)
    for i in range(data.shape[0]):
        plt.text(data[i, 0], data[i, 1], str(label[i]),
                 color=plt.cm.Set1(label[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})
    plt.xticks([])
    plt.yticks([])
    plt.title(title)
    return fig

# %%
# load datasets
input = np.load("../model/middle_output/small_input.npy",allow_pickle=True) 
input2 = np.load("../model/middle_output/small_input2.npy",allow_pickle=True) 
input3 = np.load("../model/middle_output/small_input3.npy",allow_pickle=True) 
output = np.load("../model/middle_output/small_output.npy",allow_pickle=True) 
label = np.load("../model/middle_output/small_label.npy",allow_pickle=True) 
label = np.argmax(label, axis=-1) # (4302,)
print(label.shape)
# Out:
# (15899,)

# %%
stack = input

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (15899, 768)
# (15899, 2)

# %%
color = ["#008080","#FFD700"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('DNA Embedding Before Mutation\n(Sign Prediction, Small Model)')
plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('images/tsne/input-small.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
stack = input2

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (15899, 768)
# (15899, 2)

# %%
color = ["#008080","#FFD700"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('DNA Embedding After Mutation\n(Sign Prediction, Small Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('images/tsne/input-small2.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(output.shape)
result = tsne.fit_transform(output)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (15899, 16)
# (15899, 2)

# %%
color = ["#008080","#FFD700"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('the final FC layer\n(Sign Prediction, Small Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('images/tsne/output-small.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
# load datasets
input = np.load("../model/middle_output/large_input.npy",allow_pickle=True) 
input2 = np.load("../model/middle_output/large_input2.npy",allow_pickle=True) 
input3 = np.load("../model/middle_output/large_input3.npy",allow_pickle=True) 
output = np.load("../model/middle_output/large_output.npy",allow_pickle=True) 
label = np.load("../model/middle_output/large_label.npy",allow_pickle=True) 
label = np.argmax(label, axis=-1) # (4302,)
print(label.shape)
# Out:
# (24252,)

# %%
stack = input

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (24252, 768)
# (24252, 2)

# %%
color = ["#008080","#FFD700"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('DNA Embedding Before Mutation\n(Sign Prediction, Large Model)')
plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('images/tsne/input-large.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
stack = input2

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (24252, 768)
# (24252, 2)

# %%
color = ["#008080","#FFD700"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('DNA Embedding After Mutation\n(Sign Prediction, Large Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('images/tsne/input-large2.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(output.shape)
result = tsne.fit_transform(output)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (24252, 16)
# (24252, 2)

# %%
color = ["#008080","#FFD700"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]],alpha=0.8)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('the final FC layer\n(Sign Prediction, Large Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('images/tsne/output-large.png',dpi=300, bbox_inches = 'tight')
plt.show()
