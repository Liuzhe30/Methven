# %% [markdown]
# #### small model

# %%
import numpy as np
import matplotlib.pyplot as plt

results = [{"ACC": 0.8828, "Recall": 0.8805, "Precision": 0.8777, "F1-score": 0.8791, "AUC": 0.9389},# without ATAC-seq
           {"ACC": 0.5000, "Recall": 0.7672, "Precision": 0.4891, "F1-score": 0.5973, "AUC": 0.5035},# without DNABert2
           {"ACC": 0.7809, "Recall": 0.8252, "Precision": 0.7488, "F1-score": 0.7643, "AUC": 0.8118},# replace DNABert2 with OneHot
           {"ACC": 0.8778, "Recall": 0.8690, "Precision": 0.8772, "F1-score": 0.8731, "AUC": 0.9424},# Replace BiGRUs with FC layer
           {"ACC": 0.9120, "Recall": 0.9063, "Precision": 0.9174, "F1-score": 0.9116, "AUC": 0.9654}] # Methven-small
data_length = len(results[0])
angles = np.linspace(0, 2 * np.pi, data_length, endpoint=False)
labels = [key for key in results[0].keys()]
score = [[v for v in result.values()] for result in results]

angles = np.concatenate((angles, [angles[0]]))
labels = np.concatenate((labels, [labels[0]]))
score_1 = np.concatenate((score[0], [score[0][0]]))
score_2 = np.concatenate((score[1], [score[1][0]]))
score_3 = np.concatenate((score[2], [score[2][0]]))
score_4 = np.concatenate((score[3], [score[3][0]]))
score_5 = np.concatenate((score[4], [score[4][0]]))

# %%
fig = plt.figure(figsize=(3,3))
ax = plt.subplot(polar = True)

plt.plot(angles, score_1, color='#008080')
plt.plot(angles, score_5, color='#808080')
plt.fill(angles, score_1, '#5F9EA0', alpha=0.4, label='_nolegend_')
plt.fill(angles, score_5, '#DCDCDC', alpha=0.6, label='_nolegend_')
ax.set_rlim(0.5, 1)

ax.set_theta_zero_location('N') 
ax.set_rlabel_position(0)
ax.set_thetagrids(angles * 180 / np.pi, labels, fontsize=9,rotation=10)
plt.yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1], ["0.5", "0.6", "0.7", "0.8", "0.9", "1"], color="#696969", size=7)
plt.ylim(0.5, 1)
ax.set_title("Without ATAC-seq\n (Small Model)")
ax.legend(labels=('Without ATAC-seq', 'Methven-small'), loc = 'center',frameon = True,bbox_to_anchor=(0.5,-0.2))
plt.savefig('images/ablation/small-atac-seq.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure(figsize=(3,3))
ax = plt.subplot(polar = True)

plt.plot(angles, score_2, color='#008080')
plt.plot(angles, score_5, color='#808080')
plt.fill(angles, score_2, '#5F9EA0', alpha=0.4, label='_nolegend_')
plt.fill(angles, score_5, '#DCDCDC', alpha=0.6, label='_nolegend_')
ax.set_rlim(0.45, 1)

ax.set_theta_zero_location('N') 
ax.set_rlabel_position(0)
ax.set_thetagrids(angles * 180 / np.pi, labels, fontsize=9,rotation=10)
plt.yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1], ["0.5", "0.6", "0.7", "0.8", "0.9", "1"], color="#696969", size=7)
plt.ylim(0.45, 1)
ax.set_title("Without DNABert2\n (Small Model)")
ax.legend(labels=('Without DNABert2', 'Methven-small'), loc = 'center',frameon = True,bbox_to_anchor=(0.5,-0.2))
plt.savefig('images/ablation/small-dnabert.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure(figsize=(3,3))
ax = plt.subplot(polar = True)

plt.plot(angles, score_3, color='#008080')
plt.plot(angles, score_5, color='#808080')
plt.fill(angles, score_3, '#5F9EA0', alpha=0.4, label='_nolegend_')
plt.fill(angles, score_5, '#DCDCDC', alpha=0.6, label='_nolegend_')
ax.set_rlim(0.5, 1)

ax.set_theta_zero_location('N') 
ax.set_rlabel_position(0)
ax.set_thetagrids(angles * 180 / np.pi, labels, fontsize=9,rotation=10)
plt.yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1], ["0.5", "0.6", "0.7", "0.8", "0.9", "1"], color="#696969", size=7)
plt.ylim(0.5, 1)
ax.set_title("Replace DNABert2 with OneHot\n (Small Model)")
ax.legend(labels=('Replace DNABert2 with OneHot', 'Methven-small'), loc = 'center',frameon = True,bbox_to_anchor=(0.5,-0.2))
plt.savefig('images/ablation/small-dnabert-onehot.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure(figsize=(3,3))
ax = plt.subplot(polar = True)

plt.plot(angles, score_4, color='#008080')
plt.plot(angles, score_5, color='#808080')
plt.fill(angles, score_4, '#5F9EA0', alpha=0.4, label='_nolegend_')
plt.fill(angles, score_5, '#DCDCDC', alpha=0.6, label='_nolegend_')
ax.set_rlim(0.5, 1)

ax.set_theta_zero_location('N') 
ax.set_rlabel_position(0)
ax.set_thetagrids(angles * 180 / np.pi, labels, fontsize=9,rotation=10)
plt.yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1], ["0.5", "0.6", "0.7", "0.8", "0.9", "1"], color="#696969", size=7)
plt.ylim(0.5, 1)
ax.set_title("Replace BiGRUs with FC layer\n (Small Model)")
ax.legend(labels=('Replace BiGRUs with FC layer', 'Methven-small'), loc = 'center',frameon = True,bbox_to_anchor=(0.5,-0.2))
plt.savefig('images/ablation/small-bigru.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# #### large model

# %%
import numpy as np
import matplotlib.pyplot as plt

results = [{"ACC": 0.8087, "Recall": 0.7953, "Precision": 0.8210, "F1-score": 0.8079, "AUC": 0.8872},# without ATAC-seq
           {"ACC": 0.5129, "Recall": 0.7761, "Precision": 0.5098, "F1-score": 0.6474, "AUC": 0.5700},# without DNABert2
           {"ACC": 0.7187, "Recall": 0.8024, "Precision": 0.6450, "F1-score": 0.7143, "AUC": 0.7479},# replace DNABert2 with OneHot
           {"ACC": 0.8183, "Recall": 0.7705, "Precision": 0.8377, "F1-score": 0.8027, "AUC": 0.8935},# Replace BiGRUs with FC layer
           {"ACC": 0.8480, "Recall": 0.8530, "Precision": 0.8463, "F1-score": 0.8490, "AUC": 0.9271}] # Methven-large
data_length = len(results[0])
angles = np.linspace(0, 2 * np.pi, data_length, endpoint=False)
labels = [key for key in results[0].keys()]
score = [[v for v in result.values()] for result in results]

angles = np.concatenate((angles, [angles[0]]))
labels = np.concatenate((labels, [labels[0]]))
score_1 = np.concatenate((score[0], [score[0][0]]))
score_2 = np.concatenate((score[1], [score[1][0]]))
score_3 = np.concatenate((score[2], [score[2][0]]))
score_4 = np.concatenate((score[3], [score[3][0]]))
score_5 = np.concatenate((score[4], [score[4][0]]))

# %%
fig = plt.figure(figsize=(3,3))
ax = plt.subplot(polar = True)

plt.plot(angles, score_1, color='#006400')
plt.plot(angles, score_5, color='#808080')
plt.fill(angles, score_1, '#2E8B57', alpha=0.4, label='_nolegend_')
plt.fill(angles, score_5, '#DCDCDC', alpha=0.6, label='_nolegend_')
ax.set_rlim(0.5, 1)

ax.set_theta_zero_location('N') 
ax.set_rlabel_position(0)
ax.set_thetagrids(angles * 180 / np.pi, labels, fontsize=9,rotation=10)
plt.yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1], ["0.5", "0.6", "0.7", "0.8", "0.9", "1"], color="#696969", size=7)
plt.ylim(0.5, 1)
ax.set_title("Without ATAC-seq\n (Large Model)")
ax.legend(labels=('Without ATAC-seq', 'Methven-large'), loc = 'center',frameon = True,bbox_to_anchor=(0.5,-0.2))
plt.savefig('images/ablation/large-atac-seq.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure(figsize=(3,3))
ax = plt.subplot(polar = True)

plt.plot(angles, score_2, color='#006400')
plt.plot(angles, score_5, color='#808080')
plt.fill(angles, score_2, '#2E8B57', alpha=0.4, label='_nolegend_')
plt.fill(angles, score_5, '#DCDCDC', alpha=0.6, label='_nolegend_')
ax.set_rlim(0.45, 1)

ax.set_theta_zero_location('N') 
ax.set_rlabel_position(0)
ax.set_thetagrids(angles * 180 / np.pi, labels, fontsize=9,rotation=10)
plt.yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1], ["0.5", "0.6", "0.7", "0.8", "0.9", "1"], color="#696969", size=7)
plt.ylim(0.45, 1)
ax.set_title("Without DNABert2\n (Large Model)")
ax.legend(labels=('Without DNABert2', 'Methven-large'), loc = 'center',frameon = True,bbox_to_anchor=(0.5,-0.2))
plt.savefig('images/ablation/large-DNABert2.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure(figsize=(3,3))
ax = plt.subplot(polar = True)

plt.plot(angles, score_3, color='#006400')
plt.plot(angles, score_5, color='#808080')
plt.fill(angles, score_3, '#2E8B57', alpha=0.4, label='_nolegend_')
plt.fill(angles, score_5, '#DCDCDC', alpha=0.6, label='_nolegend_')
ax.set_rlim(0.5, 1)

ax.set_theta_zero_location('N') 
ax.set_rlabel_position(0)
ax.set_thetagrids(angles * 180 / np.pi, labels, fontsize=9,rotation=10)
plt.yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1], ["0.5", "0.6", "0.7", "0.8", "0.9", "1"], color="#696969", size=7)
plt.ylim(0.5, 1)
ax.set_title("Replace DNABert2 with OneHot\n (Large Model)")
ax.legend(labels=('Replace DNABert2 with OneHot', 'Methven-large'), loc = 'center',frameon = True,bbox_to_anchor=(0.5,-0.2))
plt.savefig('images/ablation/large-dnabert-onehot.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure(figsize=(3,3))
ax = plt.subplot(polar = True)

plt.plot(angles, score_4, color='#006400')
plt.plot(angles, score_5, color='#808080')
plt.fill(angles, score_4, '#2E8B57', alpha=0.4, label='_nolegend_')
plt.fill(angles, score_5, '#DCDCDC', alpha=0.6, label='_nolegend_')
ax.set_rlim(0.5, 1)

ax.set_theta_zero_location('N') 
ax.set_rlabel_position(0)
ax.set_thetagrids(angles * 180 / np.pi, labels, fontsize=9,rotation=10)
plt.yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1], ["0.5", "0.6", "0.7", "0.8", "0.9", "1"], color="#696969", size=7)
plt.ylim(0.5, 1)
ax.set_title("Replace BiGRUs with FC layer\n (Large Model)")
ax.legend(labels=('Replace BiGRUs with FC layer', 'Methven-large'), loc = 'center',frameon = True,bbox_to_anchor=(0.5,-0.2))
plt.savefig('images/ablation/large-bigru.png',dpi=300, bbox_inches = 'tight')
plt.show()
