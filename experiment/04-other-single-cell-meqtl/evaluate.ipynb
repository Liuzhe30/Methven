# %% [markdown]
# #### evaluate the prediction performance of the trained model

# %% [markdown]
# #### small model

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score,recall_score, f1_score,roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load datasets
y_true = np.load('../../model/pred_results_mono_e2e/small_label.npy')
y_pred = np.load('../../model/pred_results_mono_e2e/small_predict.npy')

y_score = y_pred.argmax(axis=1)       
test_label = y_true.argmax(axis=1)                         
y_score_pro = y_pred # (212, 2)
y_one_hot = y_true
y_score_one_hot = to_categorical(y_score)

obj1 = confusion_matrix(test_label, y_score)
print('confusion_matrix\n', obj1)
print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
print('precision:{}'.format(precision_score(test_label, y_score)))
print('recall:{}'.format(recall_score(test_label, y_score)))
print('f1-score:{}'.format(f1_score(test_label, y_score)))

# update confusion matrix
sum_all1 = obj1[0][0] + obj1[0][1]
sum_all2 = obj1[1][0] + obj1[1][1]
new_obj = np.array(
    [
        [float(obj1[0][0])/sum_all1, float(obj1[0][1])/sum_all1],
        [float(obj1[1][0])/sum_all2, float(obj1[1][1])/sum_all2]
    ]
)
ax = plt.subplots(figsize=(2,3))
sns.heatmap(new_obj, fmt='.2f', cmap='bone_r', annot=True)
plt.ylabel("true label")
plt.xlabel("predict label")
plt.title('Small Model (e2e)')
plt.savefig('images/cm-small.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# confusion_matrix
#  [[214  52]
#  [ 26 210]]
# accuracy:0.8446215139442231
# precision:0.8015267175572519
# recall:0.8898305084745762
# f1-score:0.8433734939759036

# %%
from sklearn.metrics import roc_curve, auc
fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
fpr_xgb_1, tpr_xgb_1, thresholds_1 = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
auc_xgb = auc(fpr_xgb, tpr_xgb)
auc_xgb_1 = auc(fpr_xgb, tpr_xgb)
print("AUC : ", auc_xgb)
ax = plt.subplots(figsize=(3,3))
plt.title('Small Model (e2e)')
plt.plot(fpr_xgb, tpr_xgb, linewidth = 2,label='AUC=%.3f' % auc_xgb,color='#483D8B')
plt.plot([0,1],[0,1], 'k--')
plt.axis([0,1.1,0,1.1])
plt.xlabel('False Postivie Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('images/auc-small.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# AUC :  0.8979460643481849

# %%
# load datasets
y_true = np.load('../../model/pred_results_mono_finetune/small_label.npy')
y_pred = np.load('../../model/pred_results_mono_finetune/small_predict.npy')

y_score = y_pred.argmax(axis=1)       
test_label = y_true.argmax(axis=1)                         
y_score_pro = y_pred # (212, 2)
y_one_hot = y_true
y_score_one_hot = to_categorical(y_score)

obj1 = confusion_matrix(test_label, y_score)
print('confusion_matrix\n', obj1)
print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
print('precision:{}'.format(precision_score(test_label, y_score)))
print('recall:{}'.format(recall_score(test_label, y_score)))
print('f1-score:{}'.format(f1_score(test_label, y_score)))

# update confusion matrix
sum_all1 = obj1[0][0] + obj1[0][1]
sum_all2 = obj1[1][0] + obj1[1][1]
new_obj = np.array(
    [
        [float(obj1[0][0])/sum_all1, float(obj1[0][1])/sum_all1],
        [float(obj1[1][0])/sum_all2, float(obj1[1][1])/sum_all2]
    ]
)
ax = plt.subplots(figsize=(2,3))
sns.heatmap(new_obj, fmt='.2f', cmap='bone_r', annot=True)
plt.ylabel("true label")
plt.xlabel("predict label")
plt.title('Small Model (finetune)')
plt.savefig('images/ft-cm-small.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# confusion_matrix
#  [[234  32]
#  [ 24 212]]
# accuracy:0.8884462151394422
# precision:0.8688524590163934
# recall:0.8983050847457628
# f1-score:0.8833333333333333

# %%
ax = plt.subplots(figsize=(1,1))
plt.axis('off')
plt.title('Performance analysis on monocyte')
plt.savefig('images/head.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
fpr_xgb_2, tpr_xgb_2, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())  
auc_xgb = auc(fpr_xgb, tpr_xgb)
auc_xgb_2 = auc(fpr_xgb, tpr_xgb)
print("AUC : ", auc_xgb)
ax = plt.subplots(figsize=(3,3))
plt.title('Small Model (finetune)')
plt.plot(fpr_xgb, tpr_xgb, linewidth = 2,label='AUC=%.3f' % auc_xgb,color='#483D8B')
plt.plot([0,1],[0,1], 'k--')
plt.axis([0,1.1,0,1.1])
plt.xlabel('False Postivie Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('images/ft-auc-small.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# AUC :  0.9386358946683385

# %%
ax = plt.subplots(figsize=(2,3))
plt.title('Small Model')
plt.plot(fpr_xgb_1, tpr_xgb_1, linewidth = 2,label='e2e\nAUC=%.3f' % auc_xgb_1,color='#778899')
plt.plot(fpr_xgb_2, tpr_xgb_2, linewidth = 2,label='finetune\nAUC=%.3f' % auc_xgb_2,color='#000000')
plt.plot([0,1],[0,1], 'k--')
plt.axis([0,1.1,0,1.1])
plt.xlabel('False Postivie Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('images/auc-all-small.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# #### large model

# %%
# load datasets
y_true = np.load('../../model/pred_results_mono_e2e/large_label.npy')
y_pred = np.load('../../model/pred_results_mono_e2e/large_predict.npy')

y_score = y_pred.argmax(axis=1)       
test_label = y_true.argmax(axis=1)                         
y_score_pro = y_pred # (212, 2)
y_one_hot = y_true
y_score_one_hot = to_categorical(y_score)

obj1 = confusion_matrix(test_label, y_score)
print('confusion_matrix\n', obj1)
print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
print('precision:{}'.format(precision_score(test_label, y_score)))
print('recall:{}'.format(recall_score(test_label, y_score)))
print('f1-score:{}'.format(f1_score(test_label, y_score)))

# update confusion matrix
sum_all1 = obj1[0][0] + obj1[0][1]
sum_all2 = obj1[1][0] + obj1[1][1]
new_obj = np.array(
    [
        [float(obj1[0][0])/sum_all1, float(obj1[0][1])/sum_all1],
        [float(obj1[1][0])/sum_all2, float(obj1[1][1])/sum_all2]
    ]
)
ax = plt.subplots(figsize=(2,3))
sns.heatmap(new_obj, fmt='.2f', cmap='bone_r', annot=True)
plt.ylabel("true label")
plt.xlabel("predict label")
plt.title('Large Model (e2e)')
plt.savefig('images/cm-large.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# confusion_matrix
#  [[245 176]
#  [ 74 349]]
# accuracy:0.7037914691943128
# precision:0.6647619047619048
# recall:0.8250591016548463
# f1-score:0.7362869198312236

# %%
from sklearn.metrics import roc_curve, auc
fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
fpr_xgb_1, tpr_xgb_1, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())  
auc_xgb = auc(fpr_xgb, tpr_xgb)
auc_xgb_1 = auc(fpr_xgb, tpr_xgb)
print("AUC : ", auc_xgb)
ax = plt.subplots(figsize=(3,3))
plt.title('Large Model (e2e)')
plt.plot(fpr_xgb, tpr_xgb, linewidth = 2,label='AUC=%.3f' % auc_xgb,color='#483D8B')
plt.plot([0,1],[0,1], 'k--')
plt.axis([0,1.1,0,1.1])
plt.xlabel('False Postivie Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('images/auc-large.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# AUC :  0.7702460636553538

# %%
# load datasets
y_true = np.load('../../model/pred_results_mono_finetune/large_label.npy')
y_pred = np.load('../../model/pred_results_mono_finetune/large_predict.npy')

y_score = y_pred.argmax(axis=1)       
test_label = y_true.argmax(axis=1)                         
y_score_pro = y_pred # (212, 2)
y_one_hot = y_true
y_score_one_hot = to_categorical(y_score)

obj1 = confusion_matrix(test_label, y_score)
print('confusion_matrix\n', obj1)
print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
print('precision:{}'.format(precision_score(test_label, y_score)))
print('recall:{}'.format(recall_score(test_label, y_score)))
print('f1-score:{}'.format(f1_score(test_label, y_score)))

# update confusion matrix
sum_all1 = obj1[0][0] + obj1[0][1]
sum_all2 = obj1[1][0] + obj1[1][1]
new_obj = np.array(
    [
        [float(obj1[0][0])/sum_all1, float(obj1[0][1])/sum_all1],
        [float(obj1[1][0])/sum_all2, float(obj1[1][1])/sum_all2]
    ]
)
ax = plt.subplots(figsize=(2,3))
plt.title('Large Model (finetune)')
sns.heatmap(new_obj, fmt='.2f', cmap='bone_r', annot=True)
plt.ylabel("true label")
plt.xlabel("predict label")
plt.savefig('images/ft-cm-large.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# confusion_matrix
#  [[302 119]
#  [ 81 342]]
# accuracy:0.7630331753554502
# precision:0.7418655097613883
# recall:0.8085106382978723
# f1-score:0.7737556561085973

# %%
from sklearn.metrics import roc_curve, auc
fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
fpr_xgb_2, tpr_xgb_2, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())  
auc_xgb = auc(fpr_xgb, tpr_xgb)
auc_xgb_2 = auc(fpr_xgb, tpr_xgb)
print("AUC : ", auc_xgb)
ax = plt.subplots(figsize=(3,3))
plt.title('Large Model (finetune)')
plt.plot(fpr_xgb, tpr_xgb, linewidth = 2,label='AUC=%.3f' % auc_xgb,color='#483D8B')
plt.plot([0,1],[0,1], 'k--')
plt.axis([0,1.1,0,1.1])
plt.xlabel('False Postivie Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('images/ft-auc-large.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# AUC :  0.8231249017317669

# %%
ax = plt.subplots(figsize=(2,3))
plt.title('Large Model')
plt.plot(fpr_xgb_1, tpr_xgb_1, linewidth = 2,label='e2e\nAUC=%.3f' % auc_xgb_1,color='#778899')
plt.plot(fpr_xgb_2, tpr_xgb_2, linewidth = 2,label='finetune\nAUC=%.3f' % auc_xgb_2,color='#000000')
plt.plot([0,1],[0,1], 'k--')
plt.axis([0,1.1,0,1.1])
plt.xlabel('False Postivie Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.savefig('images/auc-all-large.png',dpi=300, bbox_inches = 'tight')
plt.show()
