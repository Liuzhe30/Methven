# %% [markdown]
# #### small model

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

morandi_palette = ['#8A352E', '#304E7E', '#37939A']

# %%
data = pd.read_csv('results/merged_small.csv')

ax = plt.subplots(figsize=(7.5,3))
sns.barplot(x = 'metric', y = 'value', data = data, hue = 'model', capsize = .05, ci=50,palette=morandi_palette,alpha=0.8)

plt.ylim(0.5, 1)
plt.title('Existing Methods Comparison\n (Small Model, 10-fold cross validation)')
plt.legend(loc="lower left")
plt.savefig('images/small.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
data = pd.read_csv('results/merged_small.csv')

markers = ["o", "*", "s"]
linestyles = ["-", "--", "-."]

ax = plt.subplots(figsize=(7.5,3))
sns.pointplot(
    x='metric', y='value', data=data, hue='model', palette=morandi_palette, 
    alpha=0.6, markers=markers, linestyles=linestyles, errwidth=2, capsize=0.05, ci=0,size=10, 
)

plt.ylim(0.65, 0.95)
plt.ylabel('mean value')
plt.title('Existing Methods Comparison\n (Small Model, 10-fold cross validation, average performance)')
plt.legend(loc="lower left")
plt.savefig('images/small-2.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
data = pd.read_csv('results/merged_large.csv')

ax = plt.subplots(figsize=(7.5,3))
sns.barplot(x = 'metric', y = 'value', data = data, hue = 'model', capsize = .05, ci=50,palette=morandi_palette,alpha=0.8)
plt.legend([], [], frameon=False)
plt.ylim(0.5, 1)
plt.title('Existing Methods Comparison\n (Large Model, 10-fold cross validation)')
#plt.legend(loc = 'best')
plt.savefig('images/large.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
data = pd.read_csv('results/merged_large.csv')

markers = ["o", "*", "s"]
linestyles = ["-", "--", "-."]

ax = plt.subplots(figsize=(7.5,3))
sns.pointplot(
    x='metric', y='value', data=data, hue='model', palette=morandi_palette, 
    alpha=0.6, markers=markers, linestyles=linestyles, errwidth=2, capsize=0.05, ci=0,size=10, 
)

plt.ylim(0.6, 0.9)
plt.ylabel('mean value')
plt.title('Existing Methods Comparison\n (Large Model, 10-fold cross validation, average performance)')
plt.legend([], [], frameon=False)
plt.savefig('images/large-2.png',dpi=300, bbox_inches = 'tight')
plt.show()
