# %%
import matplotlib.collections as clt
import ptitprince as pt
import scipy.stats as stats
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

type_list = ['active_promoter','strong_enhancer','txn_transition','txn_elongation','insulator','heterochrom_lo','repressed','repetitive_CNV']
output_path = 'results/'

palettes = [
    ['#EBC4C4', '#F5E1E1'],  
    ['#EBD1C4', '#F5E9E1'],  
    ['#EBDBC4', '#F5F1E1'],  
    ['#D8EBC4', '#E9F5E1'], 
    ['#C4EBD8', '#E1F5E9'],  
    ['#C4EBEB', '#E1F5F5'],  
    ['#C4D8EB', '#E1E9F5'],  
    ['#EBC4D8', '#F5E1E9'],  
]

# %%
type = type_list[0]
type_array = np.load(output_path + type + '_large_1.npy')
not_type_array = np.load(output_path + type + '_not_large_1.npy')
print(type_array.shape)
print(not_type_array.shape)

df = pd.DataFrame(type_array, columns=['score'])
df['group'] = 'group1'
df_not = pd.DataFrame(not_type_array, columns=['score'])
df_not['group'] = 'group2'

data = pd.concat([df,df_not])

y_max=6
y_min=-7

pvalue = stats.mannwhitneyu(df['score'].dropna(),df_not['score'])[1]
print(pvalue)

dx="group"; dy="score"; ort="h"; pal=palettes[0]; sigma=.2
f, ax=plt.subplots(figsize=(3, 3))
plt.ylim((-10, 10))
plt.xlim((-1, 1))
pt.RainCloud(x=dx, y=dy, data=data, palette=pal, bw=sigma, box_sym='', rain_alpha = .1,
            width_viol = .4, ax = ax)

plt.plot([0,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10], linewidth=1, color='k') 
plt.plot([0,0], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 
plt.plot([1,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 

plt.text(0.1,y_max+(y_max-y_min)/8,f'P-value<0.0005',fontsize=10,color='k')

plt.xlabel("")
plt.ylabel("hidden state")
plt.xticks([0,1],['DNA in region','DNA not in region'])
plt.title('Active Promoter (Large Model)')
plt.savefig('images/raincloud-large-' + type + '.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (973324,)
# (48964426,)
# 0.0

# %%
type = type_list[1]
type_array = np.load(output_path + type + '_large_1.npy')
not_type_array = np.load(output_path + type + '_not_large_1.npy')
print(type_array.shape)
print(not_type_array.shape)

df = pd.DataFrame(type_array, columns=['score'])
df['group'] = 'group1'
df_not = pd.DataFrame(not_type_array, columns=['score'])
df_not['group'] = 'group2'

data = pd.concat([df,df_not])

y_max=6
y_min=-7

pvalue = stats.mannwhitneyu(df['score'].dropna(),df_not['score'])[1]
print(pvalue)

dx="group"; dy="score"; ort="h"; pal=palettes[1]; sigma=.2
f, ax=plt.subplots(figsize=(3, 3))
plt.ylim((-10, 10))
plt.xlim((-1, 1))
pt.RainCloud(x=dx, y=dy, data=data, palette=pal, bw=sigma, box_sym='', rain_alpha = .3,
            width_viol = .4, ax = ax)

plt.plot([0,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10], linewidth=1, color='k') 
plt.plot([0,0], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 
plt.plot([1,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 

plt.text(0.1,y_max+(y_max-y_min)/8,f'P-value<0.0005',fontsize=10,color='k')

plt.xlabel("")
plt.ylabel("hidden state")
plt.xticks([0,1],['DNA in region','DNA not in region'])
plt.title('Strong Enhancer (Large Model)')
plt.savefig('images/raincloud-large-' + type + '.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (1796470,)
# (48142364,)
# 0.0

# %%
type = type_list[2]
type_array = np.load(output_path + type + '_large_1.npy')
not_type_array = np.load(output_path + type + '_not_large_1.npy')
print(type_array.shape)
print(not_type_array.shape)

df = pd.DataFrame(type_array, columns=['score'])
df['group'] = 'group1'
df_not = pd.DataFrame(not_type_array, columns=['score'])
df_not['group'] = 'group2'

data = pd.concat([df,df_not])

y_max=6
y_min=-7

pvalue = stats.mannwhitneyu(df['score'].dropna(),df_not['score'])[1]
print(pvalue)

dx="group"; dy="score"; ort="h"; pal=palettes[2]; sigma=.2
f, ax=plt.subplots(figsize=(3, 3))
plt.ylim((-10, 10))
plt.xlim((-1, 1))
pt.RainCloud(x=dx, y=dy, data=data, palette=pal, bw=sigma, box_sym='', rain_alpha = .3,
            width_viol = .4, ax = ax)

plt.plot([0,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10], linewidth=1, color='k') 
plt.plot([0,0], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 
plt.plot([1,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 

plt.text(0.1,y_max+(y_max-y_min)/8,f'P-value<0.0005',fontsize=10,color='k')

plt.xlabel("")
plt.ylabel("hidden state")
plt.xticks([0,1],['DNA in region','DNA not in region'])
plt.title('Txn Transition (Large Model)')
plt.savefig('images/raincloud-large-' + type + '.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (798115,)
# (49139635,)
# 0.0

# %%
type = type_list[3]
type_array = np.load(output_path + type + '_large_1.npy')
not_type_array = np.load(output_path + type + '_not_large_1.npy')
print(type_array.shape)
print(not_type_array.shape)

df = pd.DataFrame(type_array, columns=['score'])
df['group'] = 'group1'
df_not = pd.DataFrame(not_type_array, columns=['score'])
df_not['group'] = 'group2'

data = pd.concat([df,df_not])

y_max=6
y_min=-7

pvalue = stats.mannwhitneyu(df['score'].dropna(),df_not['score'])[1]
print(pvalue)

dx="group"; dy="score"; ort="h"; pal=palettes[3]; sigma=.2
f, ax=plt.subplots(figsize=(3, 3))
plt.ylim((-10, 10))
plt.xlim((-1, 1))
pt.RainCloud(x=dx, y=dy, data=data, palette=pal, bw=sigma, box_sym='', rain_alpha = .3,
            width_viol = .4, ax = ax)

plt.plot([0,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10], linewidth=1, color='k') 
plt.plot([0,0], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 
plt.plot([1,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 

plt.text(0.1,y_max+(y_max-y_min)/8,f'P-value<0.0005',fontsize=10,color='k')

plt.xlabel("")
plt.ylabel("hidden state")
plt.xticks([0,1],['DNA in region','DNA not in region'])
plt.title('Txn Elongation (Large Model)')
plt.savefig('images/raincloud-large-' + type + '.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (5370113,)
# (44567637,)
# 0.0

# %%
type = type_list[4]
type_array = np.load(output_path + type + '_large_1.npy')
not_type_array = np.load(output_path + type + '_not_large_1.npy')
print(type_array.shape)
print(not_type_array.shape)

df = pd.DataFrame(type_array, columns=['score'])
df['group'] = 'group1'
df_not = pd.DataFrame(not_type_array, columns=['score'])
df_not['group'] = 'group2'

data = pd.concat([df,df_not])

y_max=6
y_min=-7

pvalue = stats.mannwhitneyu(df['score'].dropna(),df_not['score'])[1]
print(pvalue)

dx="group"; dy="score"; ort="h"; pal=palettes[4]; sigma=.2
f, ax=plt.subplots(figsize=(3, 3))
plt.ylim((-10, 10))
plt.xlim((-1, 1))
pt.RainCloud(x=dx, y=dy, data=data, palette=pal, bw=sigma, box_sym='', rain_alpha = .3,
            width_viol = .4, ax = ax)

plt.plot([0,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10], linewidth=1, color='k') 
plt.plot([0,0], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 
plt.plot([1,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 

plt.text(0.1,y_max+(y_max-y_min)/8,f'P-value<0.0005',fontsize=10,color='k')

plt.xlabel("")
plt.ylabel("hidden state")
plt.xticks([0,1],['DNA in region','DNA not in region'])
plt.title('Insulator (Large Model)')
plt.savefig('images/raincloud-large-' + type + '.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (386777,)
# (49550973,)
# 0.0

# %%
type = type_list[5]
type_array = np.load(output_path + type + '_large_1.npy')
not_type_array = np.load(output_path + type + '_not_large_1.npy')
print(type_array.shape)
print(not_type_array.shape)

df = pd.DataFrame(type_array, columns=['score'])
df['group'] = 'group1'
df_not = pd.DataFrame(not_type_array, columns=['score'])
df_not['group'] = 'group2'

data = pd.concat([df,df_not])

y_max=6
y_min=-7

pvalue = stats.mannwhitneyu(df['score'].dropna(),df_not['score'])[1]
print(pvalue)

dx="group"; dy="score"; ort="h"; pal=palettes[5]; sigma=.2
f, ax=plt.subplots(figsize=(3, 3))
plt.ylim((-10, 10))
plt.xlim((-1, 1))
pt.RainCloud(x=dx, y=dy, data=data, palette=pal, bw=sigma, box_sym='', rain_alpha = .3,
            width_viol = .4, ax = ax)

plt.plot([0,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10], linewidth=1, color='k') 
plt.plot([0,0], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 
plt.plot([1,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 

plt.text(0.1,y_max+(y_max-y_min)/8,f'P-value<0.0005',fontsize=10,color='k')

plt.xlabel("")
plt.ylabel("hidden state")
plt.xticks([0,1],['DNA in region','DNA not in region'])
plt.title('Heterochrom/lo (Large Model)')
plt.savefig('images/raincloud-large-' + type + '.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (24924892,)
# (25012858,)
# 0.0

# %%
type = type_list[6]
type_array = np.load(output_path + type + '_large_1.npy')
not_type_array = np.load(output_path + type + '_not_large_1.npy')
print(type_array.shape)
print(not_type_array.shape)

df = pd.DataFrame(type_array, columns=['score'])
df['group'] = 'group1'
df_not = pd.DataFrame(not_type_array, columns=['score'])
df_not['group'] = 'group2'

data = pd.concat([df,df_not])

y_max=6
y_min=-7

pvalue = stats.mannwhitneyu(df['score'].dropna(),df_not['score'])[1]
print(pvalue)

dx="group"; dy="score"; ort="h"; pal=palettes[6]; sigma=.2
f, ax=plt.subplots(figsize=(3, 3))
plt.ylim((-10, 10))
plt.xlim((-1, 1))
pt.RainCloud(x=dx, y=dy, data=data, palette=pal, bw=sigma, box_sym='', rain_alpha = .3,
            width_viol = .4, ax = ax)

plt.plot([0,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10], linewidth=1, color='k') 
plt.plot([0,0], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 
plt.plot([1,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 

plt.text(0.1,y_max+(y_max-y_min)/8,f'P-value<0.0005',fontsize=10,color='k')

plt.xlabel("")
plt.ylabel("hidden state")
plt.xticks([0,1],['DNA in region','DNA not in region'])
plt.title('Repressed (Large Model)')
plt.savefig('images/raincloud-large-' + type + '.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (2472967,)
# (47464783,)
# 0.0

# %%
type = type_list[7]
type_array = np.load(output_path + type + '_large_1.npy')
not_type_array = np.load(output_path + type + '_not_large_1.npy')
print(type_array.shape)
print(not_type_array.shape)

df = pd.DataFrame(type_array, columns=['score'])
df['group'] = 'group1'
df_not = pd.DataFrame(not_type_array, columns=['score'])
df_not['group'] = 'group2'

data = pd.concat([df,df_not])

y_max=6
y_min=-7

pvalue = stats.mannwhitneyu(df['score'].dropna(),df_not['score'])[1]
print(pvalue)

dx="group"; dy="score"; ort="h"; pal=palettes[7]; sigma=.2
f, ax=plt.subplots(figsize=(3, 3))
plt.ylim((-10, 10))
plt.xlim((-1, 1))
pt.RainCloud(x=dx, y=dy, data=data, palette=pal, bw=sigma, box_sym='', rain_alpha = .3,
            width_viol = .4, ax = ax)

plt.plot([0,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10], linewidth=1, color='k') 
plt.plot([0,0], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 
plt.plot([1,1], [y_max+(y_max-y_min)/10,y_max+(y_max-y_min)/10-(y_max-y_min)/20], linewidth=1, color='k') 

plt.text(0.1,y_max+(y_max-y_min)/8,f'P-value<0.0005',fontsize=10,color='k')

plt.xlabel("")
plt.ylabel("hidden state")
plt.xticks([0,1],['DNA in region','DNA not in region'])
plt.title('Repetitive/CNV (Large Model)')
plt.savefig('images/raincloud-large-' + type + '.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (54507,)
# (49883278,)
# 0.0
